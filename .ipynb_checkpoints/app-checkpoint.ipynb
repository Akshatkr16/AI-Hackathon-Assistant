# %%
import streamlit as st
st.title("SupplyChain AI Assistant")
st.write("Future AI Engineer 🚀")
# Out:
# 2026-06-13 13:17:58.871
# ...
#   command:
#
#     streamlit run C:\Users\AKSHAT KUMAR\anaconda3\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
